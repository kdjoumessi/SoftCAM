# %%
import torchvision.models as models

# %%
# Load the pretrained Inception v3 model
inception = models.inception_v4(weights=Inception_V4_Weights.IMAGENET1K_V1)

# Set to evaluation mode
#inception.eval()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load the pretrained Inception v3 model
# ----> 2 inception = models.inception_v4(weights=Inception_V4_Weights.IMAGENET1K_V1)
#       4 # Set to evaluation mode
#       5 #inception.eval()
#
# AttributeError: module 'torchvision.models' has no attribute 'inception_v4'
